# %%
import pandas as pd
import numpy as np
from scipy.stats import ttest_ind, chi2_contingency
from IPython.display import display
import sys
import os
sys.path.append(os.path.abspath("..")) 
from utils.variables import bin_vars, cat_vars, numeric_vars
pd.set_option('display.max_rows', None)

# %%
# Load the dataset
df = pd.read_csv('../data/student_preprocessed.csv')

# %%
# 1. T-tests between groups for numeric variables

# Collect results
results = []

for var in bin_vars:
    for col in numeric_vars:
        group0 = df[df[var] == 0][col]
        group1 = df[df[var] == 1][col]
        
        # Calculate variance ratio
        var0 = np.var(group0, ddof=1)
        var1 = np.var(group1, ddof=1)
        ratio = max(var0, var1) / min(var0, var1)
        
        # Choose t-test type
        if ratio > 1.5:
            t_stat, p_val = ttest_ind(group0, group1, equal_var=False)
            test_type = "Welch's t-test"
        else:
            t_stat, p_val = ttest_ind(group0, group1, equal_var=True)
            test_type = "Student's t-test"
        
        results.append({
            "Group Variable": var,
            "Numeric Variable": col,
            "Test Type": test_type,
            "t-statistic": round(t_stat, 3),
            "p-value": round(p_val, 5),
            "Variance Ratio": round(ratio, 2)
        })

# Convert to DataFrame
t_results_df = pd.DataFrame(results)

# Sort by p-value (ascending)
t_results_df = t_results_df.sort_values(by="p-value", ascending=True).reset_index(drop=True)

# Display nicely
display(t_results_df)
# Out:
#         Group Variable Numeric Variable         Test Type  t-statistic  \
# 0        higher_binary             Fedu    Welch's t-test       -6.459
# 1           sex_binary             Walc    Welch's t-test       -8.187
# 2           sex_binary             Dalc    Welch's t-test       -6.850
# 3      internet_binary             Medu  Student's t-test       -7.020
# 4      internet_binary             Fedu  Student's t-test       -4.748
# 5        higher_binary        studytime  Student's t-test       -4.876
# 6        higher_binary         failures    Welch's t-test        5.062
# 7           sex_binary        studytime  Student's t-test        5.361
# 8        higher_binary             Medu    Welch's t-test       -7.016
# 9      romantic_binary              age  Student's t-test       -4.623
# 10       higher_binary               G2  Student's t-test       -8.951
# 11       higher_binary               G1    Welch's t-test      -12.434
# 12       higher_binary              age  Student's t-test        7.005
# 13       higher_binary               G3  Student's t-test       -8.958
# 14    schoolsup_binary              age  Student's t-test        4.331
# 15     internet_binary       traveltime    Welch's t-test        4.344
# 16     internet_binary               G3  Student's t-test       -3.860
# 17   activities_binary         freetime  Student's t-test       -3.868
# 18     internet_binary               G2  Student's t-test       -3.804
# 19          sex_binary         freetime  Student's t-test       -3.762
# 20       famsup_binary        studytime  Student's t-test       -3.689
# 21     internet_binary               G1  Student's t-test       -3.595
# 22          sex_binary           health  Student's t-test       -3.585
# 23       famsup_binary             Fedu  Student's t-test       -3.471
# 24          sex_binary               G3  Student's t-test        3.311
# 25      nursery_binary             Medu  Student's t-test       -3.229
# 26       famsup_binary             Medu  Student's t-test       -3.087
# 27   activities_binary             Medu  Student's t-test       -3.058
# 28          sex_binary             Medu  Student's t-test       -3.052
# 29         paid_binary             Medu  Student's t-test       -2.918
# 30          sex_binary               G1  Student's t-test        2.663
# 31          sex_binary               G2  Student's t-test        2.660
# 32       higher_binary         freetime  Student's t-test        2.624
# 33       higher_binary         absences    Welch's t-test        2.669
# 34       famsup_binary              age  Student's t-test        2.605
# 35       higher_binary             Dalc    Welch's t-test        2.641
# 36    schoolsup_binary             Walc  Student's t-test        2.512
# 37     romantic_binary               G2  Student's t-test        2.503
# 38         paid_binary             Fedu  Student's t-test       -2.418
# 39     internet_binary            goout  Student's t-test       -2.372
# 40     romantic_binary               G3  Student's t-test        2.314
# 41    schoolsup_binary        studytime  Student's t-test       -2.281
# 42   activities_binary            goout  Student's t-test       -2.262
# 43    schoolsup_binary               G3    Welch's t-test        2.247
# 44       higher_binary             Walc  Student's t-test        2.153
# 45          sex_binary             Fedu  Student's t-test       -2.142
# 46          sex_binary           famrel  Student's t-test       -2.131
# 47   activities_binary               G1  Student's t-test       -2.045
# 48     internet_binary         failures    Welch's t-test        2.052
# 49   activities_binary             Fedu  Student's t-test       -2.034
# 50     romantic_binary         absences  Student's t-test       -2.028
# 51     internet_binary         absences    Welch's t-test       -1.991
# 52    schoolsup_binary               G2    Welch's t-test        1.994
# 53      nursery_binary             Walc  Student's t-test        1.932
# 54     romantic_binary               G1  Student's t-test        1.912
# 55      nursery_binary             Fedu  Student's t-test       -1.910
# 56     internet_binary           famrel    Welch's t-test       -1.854
# 57       higher_binary       traveltime  Student's t-test        1.835
# 58    schoolsup_binary               G1  Student's t-test        1.831
# 59    schoolsup_binary         absences    Welch's t-test        1.830
# 60          sex_binary         failures    Welch's t-test       -1.792
# 61   activities_binary        studytime  Student's t-test       -1.787
# 62     romantic_binary         failures  Student's t-test       -1.782
# 63       higher_binary            goout  Student's t-test        1.762
# 64      nursery_binary             Dalc    Welch's t-test        1.763
# 65     romantic_binary             Fedu  Student's t-test        1.725
# 66   activities_binary               G2  Student's t-test       -1.712
# 67       famsup_binary             Walc  Student's t-test        1.672
# 68     internet_binary         freetime  Student's t-test       -1.613
# 69         paid_binary           health  Student's t-test       -1.611
# 70         paid_binary               G1  Student's t-test        1.600
# 71     internet_binary             Walc  Student's t-test       -1.546
# 72   activities_binary               G3  Student's t-test       -1.524
# 73       famsup_binary               G3  Student's t-test       -1.509
# 74      nursery_binary         failures    Welch's t-test        1.502
# 75     romantic_binary             Dalc    Welch's t-test       -1.496
# 76         paid_binary       traveltime    Welch's t-test        1.508
# 77          sex_binary            goout  Student's t-test       -1.482
# 78    schoolsup_binary            goout  Student's t-test        1.481
# 79   activities_binary           famrel  Student's t-test       -1.467
# 80         paid_binary               G3  Student's t-test        1.399
# 81   activities_binary              age  Student's t-test        1.383
# 82         paid_binary         failures    Welch's t-test       -1.359
# 83         paid_binary             Dalc  Student's t-test       -1.324
# 84         paid_binary         absences    Welch's t-test        1.318
# 85         paid_binary         freetime  Student's t-test        1.263
# 86       higher_binary           famrel  Student's t-test       -1.228
# 87     romantic_binary           famrel  Student's t-test        1.144
# 88    schoolsup_binary       traveltime  Student's t-test        1.141
# 89          sex_binary              age  Student's t-test        1.112
# 90     internet_binary             Dalc  Student's t-test       -1.090
# 91         paid_binary               G2    Welch's t-test        1.102
# 92      nursery_binary        studytime  Student's t-test       -1.085
# 93       famsup_binary         absences  Student's t-test       -1.069
# 94      nursery_binary           famrel  Student's t-test       -1.045
# 95          sex_binary       traveltime  Student's t-test       -1.041
# 96      nursery_binary         absences  Student's t-test        1.033
# 97      nursery_binary               G2  Student's t-test       -1.015
# 98       famsup_binary       traveltime  Student's t-test        1.000
# 99       famsup_binary               G1  Student's t-test       -0.974
# 100      famsup_binary               G2  Student's t-test       -0.971
# 101    internet_binary        studytime  Student's t-test       -0.955
# 102        paid_binary             Walc  Student's t-test       -0.908
# 103  activities_binary       traveltime  Student's t-test        0.849
# 104    romantic_binary        studytime  Student's t-test       -0.841
# 105  activities_binary             Walc  Student's t-test       -0.835
# 106        paid_binary           famrel  Student's t-test       -0.813
# 107     nursery_binary               G1  Student's t-test       -0.793
# 108    romantic_binary             Medu  Student's t-test        0.789
# 109     nursery_binary               G3  Student's t-test       -0.732
# 110   schoolsup_binary             Dalc  Student's t-test        0.714
# 111    romantic_binary         freetime  Student's t-test       -0.690
# 112   schoolsup_binary             Fedu  Student's t-test       -0.600
# 113    internet_binary           health  Student's t-test        0.580
# 114   schoolsup_binary           health  Student's t-test       -0.579
# 115  activities_binary             Dalc  Student's t-test       -0.575
# 116   schoolsup_binary             Medu  Student's t-test        0.564
# 117     nursery_binary              age  Student's t-test        0.546
# 118         sex_binary         absences  Student's t-test       -0.543
# 119    romantic_binary             Walc  Student's t-test        0.508
# 120      famsup_binary           health  Student's t-test       -0.478
# 121     nursery_binary            goout  Student's t-test       -0.475
# 122    romantic_binary           health  Student's t-test        0.459
# 123      higher_binary           health  Student's t-test       -0.440
# 124      famsup_binary            goout  Student's t-test       -0.439
# 125      famsup_binary             Dalc  Student's t-test        0.429
# 126   schoolsup_binary         freetime  Student's t-test        0.397
# 127      famsup_binary           famrel  Student's t-test       -0.387
# 128  activities_binary         absences  Student's t-test        0.385
# 129    internet_binary              age  Student's t-test       -0.334
# 130  activities_binary           health  Student's t-test       -0.331
# 131   schoolsup_binary           famrel  Student's t-test        0.306
# 132     nursery_binary       traveltime  Student's t-test        0.293
# 133     nursery_binary         freetime  Student's t-test        0.180
# 134      famsup_binary         failures  Student's t-test        0.178
# 135        paid_binary            goout  Student's t-test        0.170
# 136        paid_binary              age  Student's t-test        0.139
# 137    romantic_binary       traveltime  Student's t-test       -0.121
# 138      famsup_binary         freetime  Student's t-test       -0.096
# 139        paid_binary        studytime  Student's t-test        0.059
# 140     nursery_binary           health  Student's t-test       -0.043
# 141   schoolsup_binary         failures  Student's t-test        0.019
# 142  activities_binary         failures  Student's t-test       -0.014
# 143    romantic_binary            goout  Student's t-test        0.013
#
#      p-value  Variance Ratio
# 0    0.00000            1.96
# 1    0.00000            1.78
# 2    0.00000            2.99
# 3    0.00000            1.13
# 4    0.00000            1.28
# 5    0.00000            1.24
# 6    0.00000            3.73
# 7    0.00000            1.06
# 8    0.00000            1.81
# 9    0.00000            1.17
# 10   0.00000            1.28
# 11   0.00000            2.01
# 12   0.00000            1.33
# 13   0.00000            1.06
# 14   0.00002            1.08
# 15   0.00002            1.63
# 16   0.00012            1.22
# 17   0.00012            1.15
# 18   0.00016            1.35
# 19   0.00018            1.10
# 20   0.00024            1.08
# 141  0.98488            1.10
# 142  0.98862            1.37
# 143  0.98946            1.14

# %%
# 2. Chi-square tests for categorical variables

# Store results
results = []

# Loop over unique pairs
for i in range(len(cat_vars)):
    for j in range(i+1, len(cat_vars)):
        var1 = cat_vars[i]
        var2 = cat_vars[j]
        
        # Contingency table
        table = pd.crosstab(df[var1], df[var2])
        
        # Chi-square test
        chi2, p, dof, expected = chi2_contingency(table)
        
        # Cramer's V effect size
        n = table.sum().sum()
        min_dim = min(table.shape) - 1
        cramers_v = np.sqrt(chi2 / (n * min_dim)) if min_dim > 0 else np.nan
        
        # Append to results
        results.append({
            'Variable 1': var1,
            'Variable 2': var2,
            'Chi2': chi2,
            'p-value': p,
            'dof': dof,
            "Cramer's V": cramers_v
        })

# Convert to DataFrame
chi2_df = pd.DataFrame(results)

# Sort by p-value or effect size if desired
chi2_df = chi2_df.sort_values('p-value')

# Display
pd.set_option('display.max_rows', None)
display(chi2_df)
# Out:
#             Variable 1         Variable 2        Chi2       p-value  dof  \
# 187               Dalc               Walc  442.393095  4.575918e-84   16
# 135               Medu               Fedu  388.485086  9.405231e-73   16
# 180           freetime              goout  144.610236  8.986106e-23   16
# 185              goout               Walc  137.689487  2.039735e-21   16
# 17          sex_binary               Walc   75.112528  1.886326e-15    4
# 105      higher_binary           failures   67.073982  1.805605e-14    3
# 16          sex_binary               Dalc   57.773635  8.513228e-12    4
# 113    internet_binary               Medu   48.732837  6.638317e-10    4
# 11          sex_binary          studytime   43.276444  2.149879e-09    3
# 104      higher_binary          studytime   34.300357  1.712027e-07    3
# 167          studytime               Walc   52.910376  4.273380e-07   12
# 136               Medu         traveltime   51.966120  6.285980e-07   12
# 101      higher_binary               Medu   30.593912  3.704442e-06    4
# 138               Medu           failures   47.455409  3.886780e-06   12
# 184              goout               Dalc   54.667446  4.032309e-06   16
# 114    internet_binary               Fedu   28.921024  8.111540e-06    4
# 102      higher_binary               Fedu   28.174460  1.149750e-05    4
# 145               Fedu         traveltime   43.783925  1.662139e-05   12
# 115    internet_binary         traveltime   24.697926  1.785692e-05    3
# 164          studytime           freetime   41.068687  4.772370e-05   12
# 182           freetime               Walc   47.499747  5.689981e-05   16
# 166          studytime               Dalc   37.370880  1.944765e-04   12
# 80   activities_binary           freetime   20.389774  4.182506e-04    4
# 14          sex_binary           freetime   19.322558  6.791553e-04    4
# 46       famsup_binary          studytime   16.651411  8.335183e-04    3
# 1           sex_binary      famsup_binary   10.344457  1.298641e-03    1
# 35    schoolsup_binary               Walc   17.218322  1.752970e-03    4
# 3           sex_binary  activities_binary    9.592178  1.954080e-03    1
# 160         traveltime               Walc   31.017990  1.957609e-03   12
# 165          studytime              goout   30.563882  2.295014e-03   12
# 88      nursery_binary               Medu   16.592339  2.319121e-03    4
# 181           freetime               Dalc   35.803468  3.080822e-03   16
# 172           failures               Dalc   28.980801  3.965931e-03   12
# 162          studytime           failures   23.876637  4.500665e-03    9
# 7           sex_binary    romantic_binary    7.415931  6.464884e-03    1
# 108      higher_binary              goout   14.181020  6.739171e-03    4
# 0           sex_binary   schoolsup_binary    7.304221  6.879282e-03    1
# 28    schoolsup_binary         traveltime    5.266118  1.533161e-01    3
# 9           sex_binary               Fedu    6.489343  1.654631e-01    4
# 73   activities_binary    romantic_binary    1.915031  1.664055e-01    1
# 188               Dalc             health   21.218183  1.702755e-01   16
# 120    internet_binary              goout    6.344485  1.748567e-01    4
# 5           sex_binary      higher_binary    1.826610  1.765285e-01    1
# 12          sex_binary           failures    4.900850  1.792030e-01    3
# 66         paid_binary              goout    6.263175  1.803374e-01    4
# 129    romantic_binary             famrel    6.261846  1.804283e-01    4
# 81   activities_binary              goout    6.186384  1.856547e-01    4
# 50       famsup_binary              goout    6.130477  1.896137e-01    4
# 49       famsup_binary           freetime    6.117388  1.905515e-01    4
# 110      higher_binary               Walc    6.045607  1.957681e-01    4
# 13          sex_binary             famrel    6.019325  1.977097e-01    4
# 119    internet_binary           freetime    5.978163  2.007850e-01    4
# 170           failures           freetime   15.773224  2.018450e-01   12
# 154         traveltime          studytime   12.141829  2.054313e-01    9
# 60         paid_binary               Fedu    5.853209  2.103822e-01    4
# 128    romantic_binary           failures    4.448631  2.169183e-01    3
# 178             famrel               Walc   19.993521  2.205126e-01   16
# 95      nursery_binary              goout    5.712170  2.216994e-01    4
# 32    schoolsup_binary           freetime    5.684728  2.239626e-01    4
# 124    romantic_binary               Medu    5.539535  2.362761e-01    4
# 63         paid_binary           failures    4.186955  2.419712e-01    3
# 77   activities_binary          studytime    4.049498  2.561687e-01    3
# 189               Walc             health   18.860844  2.759454e-01   16
# 31    schoolsup_binary             famrel    5.111373  2.760597e-01    4
# 15          sex_binary              goout    5.062882  2.809060e-01    4
# 92      nursery_binary           failures    3.818000  2.817994e-01    3
# 71   activities_binary      higher_binary    1.033576  3.093202e-01    1
# 146               Fedu          studytime   13.853118  3.101862e-01   12
# 4           sex_binary     nursery_binary    1.021126  3.122521e-01    1
# 69         paid_binary             health    4.673235  3.224975e-01    4
# 93      nursery_binary             famrel    4.661055  3.238753e-01    4
# 122    internet_binary               Walc    4.413739  3.528987e-01    4
# 85      nursery_binary      higher_binary    0.856282  3.547811e-01    1
# 65         paid_binary           freetime    4.393007  3.554233e-01    4
# 70   activities_binary     nursery_binary    0.833885  3.611516e-01    1
# 61         paid_binary         traveltime    3.126806  3.724844e-01    3
# 27    schoolsup_binary               Fedu    4.168055  3.837396e-01    4
# 82   activities_binary               Dalc    4.149489  3.861526e-01    4
# 97      nursery_binary               Walc    4.147280  3.864404e-01    4
# 84   activities_binary             health    4.030809  4.018523e-01    4
# 106      higher_binary             famrel    4.012270  4.043478e-01    4
# 48       famsup_binary             famrel    3.847850  4.269886e-01    4
# 112    internet_binary    romantic_binary    0.625769  4.289115e-01    1
# 68         paid_binary               Walc    3.823407  4.304323e-01    4
# 20    schoolsup_binary        paid_binary    0.581269  4.458152e-01    1
# 10          sex_binary         traveltime    2.427769  4.884864e-01    3
# 142               Medu               Dalc   15.423885  4.938389e-01   16
# 137               Medu          studytime   11.327828  5.010523e-01   12
# 131    romantic_binary              goout    3.342267  5.022634e-01    4
# 144               Medu             health   15.124580  5.155337e-01   16
# 79   activities_binary             famrel    3.237961  5.188216e-01    4
# 21    schoolsup_binary  activities_binary    0.412550  5.206781e-01    1
# 57         paid_binary    internet_binary    0.378548  5.383815e-01    1
# 39       famsup_binary     nursery_binary    0.368346  5.439072e-01    1
# 140               Medu           freetime   14.673461  5.486720e-01   16
# 157         traveltime           freetime   10.588897  5.644393e-01   12
# 67         paid_binary               Dalc    2.818802  5.885916e-01    4
# 33    schoolsup_binary              goout    2.764343  5.980033e-01    4
# 143               Medu               Walc   13.901987  6.060155e-01   16
# 42       famsup_binary    romantic_binary    0.262682  6.082835e-01    1
# 24    schoolsup_binary    internet_binary    0.259303  6.105993e-01    1
# 55         paid_binary     nursery_binary    0.244750  6.207961e-01    1
# 171           failures              goout    9.921230  6.228711e-01   12
# 87      nursery_binary    romantic_binary    0.233552  6.289028e-01    1
# 116    internet_binary          studytime    1.585076  6.627784e-01    3
# 111      higher_binary             health    2.213502  6.965581e-01    4
# 34    schoolsup_binary               Dalc    2.196072  6.997485e-01    4
# 156         traveltime             famrel    8.941427  7.079251e-01   12
# 121    internet_binary               Dalc    2.109452  7.156361e-01    4
# 64         paid_binary             famrel    2.088125  7.195542e-01    4
# 91      nursery_binary          studytime    1.308454  7.271266e-01    3
# 56         paid_binary      higher_binary    0.119960  7.290777e-01    1
# 90      nursery_binary         traveltime    1.284463  7.328259e-01    3
# 98      nursery_binary             health    2.011518  7.336403e-01    4
# 151               Fedu               Dalc   12.094088  7.374779e-01   16
# 161         traveltime             health    8.461922  7.480717e-01   12
# 134    romantic_binary             health    1.871724  7.593372e-01    4
# 58         paid_binary    romantic_binary    0.087150  7.678318e-01    1
# 22    schoolsup_binary     nursery_binary    0.086183  7.690870e-01    1
# 149               Fedu           freetime   11.585726  7.719719e-01   16
# 174           failures             health    8.101252  7.771687e-01   12
# 62         paid_binary          studytime    1.049234  7.893412e-01    3
# 76   activities_binary         traveltime    1.014688  7.976979e-01    3
# 133    romantic_binary               Walc    1.635067  8.024762e-01    4
# 139               Medu             famrel   11.103061  8.030796e-01   16
# 26    schoolsup_binary               Medu    1.367522  8.498197e-01    4
# 126    romantic_binary         traveltime    0.669220  8.804187e-01    3
# 123    internet_binary             health    1.175585  8.821017e-01    4
# 36    schoolsup_binary             health    1.071119  8.988270e-01    4
# 30    schoolsup_binary           failures    0.542775  9.093983e-01    3
# 38       famsup_binary  activities_binary    0.011819  9.134277e-01    1
# 86      nursery_binary    internet_binary    0.004310  9.476537e-01    1
# 47       famsup_binary           failures    0.290807  9.617480e-01    3
# 150               Fedu              goout    7.427501  9.641150e-01   16
# 53       famsup_binary             health    0.537180  9.697820e-01    4
# 141               Medu              goout    6.334428  9.840636e-01   16
# 148               Fedu             famrel    5.807906  9.900408e-01   16
#
#      Cramer's V
# 187    0.412812
# 135    0.386843
# 180    0.236019
# 185    0.230302
# 17     0.340200
# 105    0.321481
# 16     0.298361
# 113    0.274024
# 11     0.258228
# 104    0.229894
# 167    0.164849
# 136    0.163372
# 101    0.217118
# 138    0.156120
# 184    0.145115
# 114    0.211098
# 102    0.208356
